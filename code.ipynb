# %%
import tweepy
import pandas as pd

# %%
consumer_key = 'AWitqc5VQBgEG5RZJ8Xn1ox6c'
consumer_secret = 'qD3jkhk9DWi3g6iemoobEPMq3jKgrIng5d0fl2CxUnRv1MAUSA'
access_token = '1215821400-FSIK84bf0wKcbZlB43RpYsy1F2FbFo2MbNE49FM'
access_token_secret = '3ZQjM88RUStgCoqk7G3tz24v9efgUTfFZtWusc6wK9n3U'

# %%
cursor = tweepy.Cursor(api.search_tweets, q = 'S&P500', lang='en', count=10).items()

# %%
for i in cursor:
    print(i.text)
# Out:
# RT @QCompounding: The S&amp;P500 performance in 2022 visualized: https://t.co/dFqQpINcCx
# RT @QCompounding: The S&amp;P500 performance in 2022 visualized: https://t.co/dFqQpINcCx
# RT @QCompounding: The S&amp;P500 performance in 2022 visualized: https://t.co/dFqQpINcCx
# Morning! The week went by so well.. with so much of PF mgmt, my US portfolio made into green after so much of downf… https://t.co/opgjbUgTIW
# RT @QCompounding: The S&amp;P500 performance in 2022 visualized: https://t.co/dFqQpINcCx
# RT @QCompounding: The S&amp;P500 performance in 2022 visualized: https://t.co/dFqQpINcCx
# RT @QCompounding: The S&amp;P500 performance in 2022 visualized: https://t.co/dFqQpINcCx
# RT @QCompounding: The S&amp;P500 performance in 2022 visualized: https://t.co/dFqQpINcCx
# RT @QCompounding: The S&amp;P500 performance in 2022 visualized: https://t.co/dFqQpINcCx
# ...
